# %%
import numpy as np
import pandas as pd

# %%
x = pd.read_csv(
    "../../Data/widsdatathon2025/TRAIN/TRAIN_FUNCTIONAL_CONNECTOME_MATRICES.csv"
)

# %%
x.iloc[:, 1:].head()
# Out:
#    0throw_1thcolumn  0throw_2thcolumn  0throw_3thcolumn  0throw_4thcolumn  \
# 0          0.093473          0.146902          0.067893          0.015141
# 1          0.029580          0.179323          0.112933          0.038291
# 2         -0.051580          0.139734          0.068295          0.046991
# 3          0.016273          0.204702          0.115980          0.043103
# 4          0.065771          0.098714          0.097604          0.112988
#
#    0throw_5thcolumn  0throw_6thcolumn  0throw_7thcolumn  0throw_8thcolumn  \
# 0          0.070221          0.063997          0.055382         -0.035335
# 1          0.104899          0.064250          0.008488          0.077505
# 2          0.111085          0.026978          0.151377          0.021198
# 3          0.056431          0.057615          0.055773          0.075030
# 4          0.071139          0.085607          0.019392         -0.036403
#
#    0throw_9thcolumn  0throw_10thcolumn  ...  195throw_196thcolumn  \
# 0          0.068583           0.029271  ...              0.003404
# 1         -0.004750          -0.035073  ...             -0.008409
# 2          0.083721          -0.014275  ...              0.053245
# 3          0.001033          -0.064031  ...             -0.023918
# 4         -0.020375           0.005426  ...              0.066439
#
#    195throw_197thcolumn  195throw_198thcolumn  195throw_199thcolumn  \
# 0             -0.010359             -0.050968             -0.014365
# 1             -0.008479              0.020891              0.017754
# 2             -0.028003              0.028773              0.024556
# 3             -0.005356              0.018607              0.016193
# 4             -0.076680             -0.047530             -0.031443
#
#    196throw_197thcolumn  196throw_198thcolumn  196throw_199thcolumn  \
# 0              0.128066              0.112646             -0.058980
# 1              0.094040              0.035141              0.032537
# 2              0.166343              0.058925              0.035485
# 3              0.072955              0.130135              0.056120
# 4              0.221213              0.007343              0.005763
#
#    197throw_198thcolumn  197throw_199thcolumn  198throw_199thcolumn
# 0              0.028228              0.133582              0.143372
# 1              0.075007              0.115350              0.138200
# 2              0.063661              0.042862              0.162162
# 3              0.084784              0.114148              0.190584
# 4              0.083820              0.079582              0.067269
#
# [5 rows x 19900 columns]

# %% [markdown]
# # .

# %%
cols = x.columns[1:]
feats = x[cols].to_numpy()

# %%
feats.shape
# Out:
# (1213, 19900)

# %%
abs_values = np.abs(feats)

# %%
min_ = np.min(abs_values, axis=0, keepdims=True)
max_ = np.max(abs_values, axis=0, keepdims=True)

# %%
abs_values = (abs_values - min_) / (max_ - min_)

# %%
normalized = abs_values * np.sign(feats)

# %%
np.min(normalized), np.max(normalized)
# Out:
# (np.float64(-1.0), np.float64(1.0))

# %%
normalized[1, :20]
# Out:
# array([ 0.09158499,  0.45856789,  0.40541966,  0.20102486,  0.33020227,
#         0.2023445 ,  0.03128758,  0.46038585, -0.03258008, -0.23591285,
#         0.29675868, -0.53422666, -0.17546223,  0.1058503 , -0.41284779,
#        -0.11788568, -0.51231696,  0.18005601,  0.73328483,  0.39725543])

# %% [markdown]
# # .

# %%
df = pd.DataFrame(normalized, columns=x.columns[1:])

df.head()
# Out:
#       0         1         2         3         4         5         6      \
# 0  0.290397  0.375599  0.243601  0.078965  0.220947  0.201545  0.204984
# 1  0.091585  0.458568  0.405420  0.201025  0.330202  0.202345  0.031288
# 2 -0.160041  0.357255  0.245047  0.246895  0.349688  0.084630  0.560551
# 3  0.050181  0.523513  0.416366  0.226394  0.177503  0.181388  0.206432
# 4  0.204197  0.252280  0.350346  0.594874  0.223840  0.269795  0.071676
#
#       7         8         9      ...     19890     19891     19892     19893  \
# 0 -0.209476  0.471748  0.196819  ...  0.017491 -0.056561 -0.282276 -0.074811
# 1  0.460386 -0.032580 -0.235913  ... -0.043206 -0.046295  0.115698  0.092459
# 2  0.125355  0.575894 -0.095795  ...  0.273589 -0.152896  0.159352  0.127888
# 3  0.445657  0.007003 -0.430997  ... -0.122898 -0.029241  0.103050  0.084332
# 4 -0.215828 -0.140078  0.036180  ...  0.341384 -0.418666 -0.263235 -0.163755
#
#       19894     19895     19896     19897     19898     19899
# 0  0.340933  0.492447 -0.183119  0.081080  0.500005  0.346055
# 1  0.250349  0.153625  0.101020  0.215444  0.431761  0.333571
# 2  0.442831  0.257597  0.110174  0.182854  0.160435  0.391409
# 3  0.194217  0.568904  0.174241  0.243526  0.427264  0.460011
# 4  0.588902  0.032102  0.017893  0.240756  0.297882  0.162367
#
# [5 rows x 19900 columns]

# %% [markdown]
# # function

# %%
def normalize_df(df):
    # Extract numeric columns (excluding the first column)
    numeric_cols = df.columns[1:]
    x = df[numeric_cols].to_numpy()

    # Min-max normalization preserving sign
    abs_values = np.abs(x)
    min_ = np.min(abs_values, axis=0, keepdims=True)
    max_ = np.max(abs_values, axis=0, keepdims=True)
    abs_values = (abs_values - min_) / (max_ - min_)

    # Modify DataFrame in place
    df.loc[:, numeric_cols] = abs_values * np.sign(x)

    return df  # Returns modified DataFrame

# %%
normed = normalize_df(x)

# %%
normed.head()
# Out:
#   participant_id  0throw_1thcolumn  0throw_2thcolumn  0throw_3thcolumn  \
# 0   70z8Q2xdTXM3          0.290397          0.375599          0.243601
# 1   WHWymJu6zNZi          0.091585          0.458568          0.405420
# 2   4PAQp1M6EyAo         -0.160041          0.357255          0.245047
# 3   obEacy4Of68I          0.050181          0.523513          0.416366
# 4   s7WzzDcmDOhF          0.204197          0.252280          0.350346
#
#    0throw_4thcolumn  0throw_5thcolumn  0throw_6thcolumn  0throw_7thcolumn  \
# 0          0.078965          0.220947          0.201545          0.204984
# 1          0.201025          0.330202          0.202345          0.031288
# 2          0.246895          0.349688          0.084630          0.560551
# 3          0.226394          0.177503          0.181388          0.206432
# 4          0.594874          0.223840          0.269795          0.071676
#
#    0throw_8thcolumn  0throw_9thcolumn  ...  195throw_196thcolumn  \
# 0         -0.209476          0.471748  ...              0.017491
# 1          0.460386         -0.032580  ...             -0.043206
# 2          0.125355          0.575894  ...              0.273589
# 3          0.445657          0.007003  ...             -0.122898
# 4         -0.215828         -0.140078  ...              0.341384
#
#    195throw_197thcolumn  195throw_198thcolumn  195throw_199thcolumn  \
# 0             -0.056561             -0.282276             -0.074811
# 1             -0.046295              0.115698              0.092459
# 2             -0.152896              0.159352              0.127888
# 3             -0.029241              0.103050              0.084332
# 4             -0.418666             -0.263235             -0.163755
#
#    196throw_197thcolumn  196throw_198thcolumn  196throw_199thcolumn  \
# 0              0.340933              0.492447             -0.183119
# 1              0.250349              0.153625              0.101020
# 2              0.442831              0.257597              0.110174
# 3              0.194217              0.568904              0.174241
# 4              0.588902              0.032102              0.017893
#
#    197throw_198thcolumn  197throw_199thcolumn  198throw_199thcolumn
# 0              0.081080              0.500005              0.346055
# 1              0.215444              0.431761              0.333571
# 2              0.182854              0.160435              0.391409
# 3              0.243526              0.427264              0.460011
# 4              0.240756              0.297882              0.162367
#
# [5 rows x 19901 columns]

# %%
def normalize_two_dfs(df1, df2):
    # Extract numeric columns (excluding the first column)
    numeric_cols = df1.columns[1:]  # Assuming both DataFrames have the same structure

    # Stack both DataFrames' numeric values for global normalization
    combined_x = np.vstack([df1[numeric_cols].to_numpy(), df2[numeric_cols].to_numpy()])

    # Compute global min and max
    abs_values = np.abs(combined_x)
    min_ = np.min(abs_values, axis=0, keepdims=True)
    max_ = np.max(abs_values, axis=0, keepdims=True)
    
    # Perform min-max normalization while preserving sign
    normalized_values = (abs_values - min_) / (max_ - min_) * np.sign(combined_x)

    # Split back into two DataFrames
    df1.loc[:, numeric_cols] = normalized_values[:len(df1)]
    df2.loc[:, numeric_cols] = normalized_values[len(df1):]

    return df1, df2  # Returns both normalized DataFrames

# %%
train, test = pd.read_csv(
    "../../Data/widsdatathon2025/TRAIN/TRAIN_FUNCTIONAL_CONNECTOME_MATRICES.csv"
), pd.read_csv("../../Data/widsdatathon2025/TEST/TEST_FUNCTIONAL_CONNECTOME_MATRICES.csv")

# %%
normed_train, normed_test = normalize_two_dfs(train, test)

# %%
normed_train.head()
# Out:
#   participant_id  0throw_1thcolumn  0throw_2thcolumn  0throw_3thcolumn  \
# 0   70z8Q2xdTXM3          0.120114          0.162277          0.077418
# 1   WHWymJu6zNZi          0.038010          0.198124          0.128845
# 2   4PAQp1M6EyAo         -0.066280          0.154352          0.077877
# 3   obEacy4Of68I          0.020911          0.226183          0.132323
# 4   s7WzzDcmDOhF          0.084516          0.108997          0.111342
#
#    0throw_4thcolumn  0throw_5thcolumn  0throw_6thcolumn  0throw_7thcolumn  \
# 0          0.016354          0.076694          0.069311          0.060088
# 1          0.041632          0.114618          0.069586          0.009172
# 2          0.051132          0.121382          0.029104          0.164318
# 3          0.046886          0.061614          0.062379          0.060513
# 4          0.123199          0.077698          0.092782          0.021011
#
#    0throw_8thcolumn  0throw_9thcolumn  ...  195throw_196thcolumn  \
# 0         -0.039665          0.075581  ...              0.004618
# 1          0.087176         -0.005220  ...             -0.011408
# 2          0.023737          0.092267  ...              0.072240
# 3          0.084387          0.001122  ...             -0.032450
# 4         -0.040868         -0.022443  ...              0.090140
#
#    195throw_197thcolumn  195throw_198thcolumn  195throw_199thcolumn  \
# 0             -0.015212             -0.065179             -0.017741
# 1             -0.012451              0.026716              0.021926
# 2             -0.041120              0.036796              0.030327
# 3             -0.007864              0.023795              0.019999
# 4             -0.112596             -0.060783             -0.038833
#
#    196throw_197thcolumn  196throw_198thcolumn  196throw_199thcolumn  \
# 0              0.146501              0.144346             -0.077084
# 1              0.107576              0.045031              0.042524
# 2              0.190287              0.075507              0.046378
# 3              0.083456              0.166758              0.073347
# 4              0.253054              0.009410              0.007532
#
#    197throw_198thcolumn  197throw_199thcolumn  198throw_199thcolumn
# 0              0.032827              0.162881              0.164357
# 1              0.087226              0.140650              0.158428
# 2              0.074031              0.052263              0.185898
# 3              0.098595              0.139185              0.218480
# 4              0.097473              0.097037              0.077115
#
# [5 rows x 19901 columns]

# %%
normed_test.head()
# Out:
#   participant_id  0throw_1thcolumn  0throw_2thcolumn  0throw_3thcolumn  \
# 0   Cfwaf5FX7jWK          0.704801          0.788858          0.636240
# 1   vhGrzmvA3Hjq          0.549649          0.401231          0.459882
# 2   ULliyEXjy4OV          0.179352          0.431177         -0.099281
# 3   LZfeAb1xMtql          0.171627          0.860415          0.475289
# 4   EnFOUv0YK1RG          0.162809          0.636099          0.581552
#
#    0throw_4thcolumn  0throw_5thcolumn  0throw_6thcolumn  0throw_7thcolumn  \
# 0          0.572410          0.758154          0.836157          0.786503
# 1          0.396205          0.584485          0.374893          0.444552
# 2          0.214775          0.096299          0.025699          0.414487
# 3          0.515051          0.621560          0.688040          0.544055
# 4          0.396412          0.467457          0.488478          0.490508
#
#    0throw_8thcolumn  0throw_9thcolumn  ...  195throw_196thcolumn  \
# 0          0.439388          0.603933  ...              0.109113
# 1          0.341604          0.443665  ...              0.268648
# 2          0.077571          0.416079  ...              0.069627
# 3          0.389074          0.515785  ...              0.062658
# 4          0.252145          0.328735  ...              0.428369
#
#    195throw_197thcolumn  195throw_198thcolumn  195throw_199thcolumn  \
# 0             -0.080147             -0.112746             -0.035289
# 1             -0.001063              0.106298              0.040809
# 2              0.034699             -0.072661              0.144986
# 3             -0.350891              0.155848             -0.322303
# 4              0.003280              0.371870              0.425030
#
#    196throw_197thcolumn  196throw_198thcolumn  196throw_199thcolumn  \
# 0              0.508879              0.448687             -0.016469
# 1              0.786457              0.392407              0.937728
# 2              0.659010              0.663557              0.688828
# 3              0.739922              0.762317              0.794838
# 4              0.549337              0.691739              0.584633
#
#    197throw_198thcolumn  197throw_199thcolumn  198throw_199thcolumn
# 0              0.774196              0.683514              0.637075
# 1              0.537034              0.682376              0.401260
# 2              0.703595              0.743616              0.860909
# 3              0.692455              0.833032              0.621672
# 4              0.340830              0.181106              0.618837
#
# [5 rows x 19901 columns]

# %%
normed_train.to_csv('../../Data/preprocessed/train/connectome_matrices.csv', index=False)
normed_test.to_csv('../../Data/preprocessed/test/connectome_matrices.csv', index=False)
