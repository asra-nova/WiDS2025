# %%
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %%
train_x = pd.read_csv('../../../Data/new/preprocessed/train/aux.csv')
train_y = pd.read_csv('../../../Data/new/preprocessed/train/labels.csv')

# %%
model = LogisticRegression(max_iter=1000)
model.fit(train_x.drop(columns='participant_id'), train_y['Sex_F'])
# Out:
# LogisticRegression(max_iter=1000)

# %%
coefficients = pd.Series(model.coef_[0], index=train_x.drop(columns='participant_id').columns)

# %%
top_features = coefficients.abs().nlargest(30)

# %%
top_features
# Out:
# MRI_Track_Age_at_Scan               0.876689
# SDQ_SDQ_Prosocial                   0.668755
# APQ_P_APQ_P_INV                     0.661175
# PreInt_Demos_Fam_Child_Race_10.0    0.651156
# Basic_Demos_Enroll_Year_2018        0.643671
# SDQ_SDQ_Hyperactivity               0.583336
# Barratt_Barratt_P1_Edu_6.0          0.580439
# Basic_Demos_Enroll_Year_2016        0.557281
# Barratt_Barratt_P1_Occ_5.0          0.507219
# Barratt_Barratt_P2_Occ_25.0         0.471347
# PreInt_Demos_Fam_Child_Race_7.0     0.458689
# APQ_P_APQ_P_PP                      0.455967
# APQ_P_APQ_P_PM                      0.453831
# SDQ_SDQ_Emotional_Problems          0.443216
# Barratt_Barratt_P2_Occ_15.0         0.441314
# Basic_Demos_Enroll_Year_2017        0.415488
# Barratt_Barratt_P2_Occ_5.0          0.413970
# Barratt_Barratt_P1_Occ_10.0         0.413272
# SDQ_SDQ_Peer_Problems               0.392058
# APQ_P_APQ_P_OPD                     0.386450
# Basic_Demos_Enroll_Year_2019        0.381459
# ...

# %%
plt.figure(figsize=(10,6))
top_features.sort_values().plot(kind='barh', color='skyblue')
plt.title('Top 10 Features for Sex Outcome')
plt.ylabel('Features')
plt.xlabel('Absolute Coefficient Value')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
model = LogisticRegression(max_iter=1000)
model.fit(train_x.drop(columns='participant_id'), train_y['ADHD_Outcome'])
# Out:
# LogisticRegression(max_iter=1000)

# %%
coefficients = pd.Series(model.coef_[0], index=train_x.drop(columns='participant_id').columns)

# %%
top_features = coefficients.abs().nlargest(30)
print(top_features)
# Out:
# PreInt_Demos_Fam_Child_Race_4.0     0.923168
# Barratt_Barratt_P1_Occ_20.0         0.866307
# Barratt_Barratt_P2_Edu_6.0          0.806250
# Barratt_Barratt_P1_Occ_15.0         0.746874
# Basic_Demos_Enroll_Year_2016        0.664093
# PreInt_Demos_Fam_Child_Race_9.0     0.574855
# Barratt_Barratt_P2_Occ_25.0         0.532907
# Barratt_Barratt_P1_Edu_9.0          0.470268
# Barratt_Barratt_P2_Occ_5.0          0.458693
# MRI_Track_Scan_Location_3.0         0.445888
# SDQ_SDQ_Conduct_Problems            0.437778
# PreInt_Demos_Fam_Child_Race_11.0    0.434196
# PreInt_Demos_Fam_Child_Race_2.0     0.377036
# SDQ_SDQ_Hyperactivity               0.362196
# MRI_Track_Scan_Location_2.0         0.360479
# MRI_Track_Age_at_Scan               0.358559
# Barratt_Barratt_P2_Occ_35.0         0.353133
# APQ_P_APQ_P_OPD                     0.331382
# Barratt_Barratt_P1_Edu_6.0          0.314772
# APQ_P_APQ_P_PP                      0.294885
# Barratt_Barratt_P1_Edu_15.0         0.281889
# ...

# %%
plt.figure(figsize=(10,6))
top_features.sort_values().plot(kind='barh', color='skyblue')
plt.title('Top 10 Features for ADHD Outcome')
plt.ylabel('Features')
plt.xlabel('Absolute Coefficient Value')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
model = LogisticRegression(penalty='l1', solver='liblinear')
model.fit(train_x.drop(columns='participant_id'), train_y['Sex_F'])
# Out:
# LogisticRegression(penalty='l1', solver='liblinear')

# %%
selected_features_Sex = train_x.drop(columns='participant_id').columns[model.coef_[0] != 0]
print(selected_features_Sex)
# Out:
# Index(['EHQ_EHQ_Total', 'ColorVision_CV_Score', 'APQ_P_APQ_P_CP',
#        'APQ_P_APQ_P_INV', 'APQ_P_APQ_P_OPD', 'APQ_P_APQ_P_PM',
#        'APQ_P_APQ_P_PP', 'SDQ_SDQ_Emotional_Problems', 'SDQ_SDQ_Hyperactivity',
#        'SDQ_SDQ_Peer_Problems', 'SDQ_SDQ_Prosocial', 'MRI_Track_Age_at_Scan',
#        'Basic_Demos_Enroll_Year_2016', 'Basic_Demos_Enroll_Year_2017',
#        'Basic_Demos_Enroll_Year_2018', 'Basic_Demos_Enroll_Year_2019',
#        'Basic_Demos_Study_Site_3', 'Basic_Demos_Study_Site_4',
#        'PreInt_Demos_Fam_Child_Ethnicity_1.0',
#        'PreInt_Demos_Fam_Child_Ethnicity_2.0',
#        'PreInt_Demos_Fam_Child_Race_1.0', 'PreInt_Demos_Fam_Child_Race_8.0',
#        'PreInt_Demos_Fam_Child_Race_9.0', 'PreInt_Demos_Fam_Child_Race_10.0',
#        'MRI_Track_Scan_Location_2.0', 'Barratt_Barratt_P1_Edu_6.0',
#        'Barratt_Barratt_P1_Edu_12.0', 'Barratt_Barratt_P1_Edu_15.0',
#        'Barratt_Barratt_P1_Edu_21.0', 'Barratt_Barratt_P1_Occ_5.0',
# ...

# %%
model = LogisticRegression(penalty='l1', solver='liblinear')
model.fit(train_x.drop(columns='participant_id'), train_y['ADHD_Outcome'])
# Out:
# LogisticRegression(penalty='l1', solver='liblinear')

# %%
selected_features_ADHD = train_x.drop(columns='participant_id').columns[model.coef_[0] != 0]
print(selected_features_ADHD)
# Out:
# Index(['EHQ_EHQ_Total', 'ColorVision_CV_Score', 'APQ_P_APQ_P_ID',
#        'APQ_P_APQ_P_OPD', 'APQ_P_APQ_P_PP', 'SDQ_SDQ_Conduct_Problems',
#        'SDQ_SDQ_Emotional_Problems', 'SDQ_SDQ_Hyperactivity',
#        'MRI_Track_Age_at_Scan', 'Basic_Demos_Enroll_Year_2016',
#        'Basic_Demos_Enroll_Year_2018', 'Basic_Demos_Enroll_Year_2019',
#        'Basic_Demos_Study_Site_3', 'Basic_Demos_Study_Site_4',
#        'PreInt_Demos_Fam_Child_Ethnicity_1.0',
#        'PreInt_Demos_Fam_Child_Ethnicity_2.0',
#        'PreInt_Demos_Fam_Child_Race_1.0', 'PreInt_Demos_Fam_Child_Race_2.0',
#        'PreInt_Demos_Fam_Child_Race_4.0', 'PreInt_Demos_Fam_Child_Race_8.0',
#        'PreInt_Demos_Fam_Child_Race_9.0', 'MRI_Track_Scan_Location_2.0',
#        'MRI_Track_Scan_Location_3.0', 'Barratt_Barratt_P1_Edu_6.0',
#        'Barratt_Barratt_P1_Edu_9.0', 'Barratt_Barratt_P1_Edu_12.0',
#        'Barratt_Barratt_P1_Edu_15.0', 'Barratt_Barratt_P1_Edu_18.0',
# ...

# %%
union_features = list(set(selected_features_ADHD) | set(selected_features_Sex))
pprint(union_features)
print(len(union_features))
# Out:
# ['Basic_Demos_Enroll_Year_2016',
#  'PreInt_Demos_Fam_Child_Ethnicity_2.0',
#  'Barratt_Barratt_P2_Occ_25.0',
#  'SDQ_SDQ_Prosocial',
#  'PreInt_Demos_Fam_Child_Race_4.0',
#  'PreInt_Demos_Fam_Child_Ethnicity_1.0',
#  'Barratt_Barratt_P2_Occ_20.0',
#  'Basic_Demos_Enroll_Year_2017',
#  'Barratt_Barratt_P1_Edu_18.0',
#  'Barratt_Barratt_P2_Edu_15.0',
#  'PreInt_Demos_Fam_Child_Race_9.0',
#  'SDQ_SDQ_Conduct_Problems',
#  'Barratt_Barratt_P1_Occ_15.0',
#  'Barratt_Barratt_P1_Occ_20.0',
#  'SDQ_SDQ_Peer_Problems',
#  'Basic_Demos_Study_Site_4',
#  'Barratt_Barratt_P1_Occ_40.0',
#  'Barratt_Barratt_P2_Occ_30.0',
#  'PreInt_Demos_Fam_Child_Race_1.0',
#  'MRI_Track_Scan_Location_2.0',
#  'Barratt_Barratt_P1_Edu_12.0',
#  'Barratt_Barratt_P2_Edu_12.0',
#  'Barratt_Barratt_P2_Occ_40.0',
#  'Barratt_Barratt_P2_Occ_45.0',
#  'Barratt_Barratt_P2_Edu_18.0',
#  'Barratt_Barratt_P2_Occ_5.0',
#  'PreInt_Demos_Fam_Child_Race_10.0',
#  'Barratt_Barratt_P1_Occ_35.0',
#  'APQ_P_APQ_P_CP',
# ...

# %%
print(len(train_x.columns))
# Out:
# 76

# %%
train_x_selected = train_x[['participant_id'] + union_features]
train_x_selected.to_csv('../../../Data/new/preprocessed_selected_features/train/aux.csv', index=False)

# %%
test_x = pd.read_csv('../../../Data/new/preprocessed/test/aux.csv')
test_x_selected = test_x[['participant_id'] + union_features]
test_x_selected.to_csv('../../../Data/new/preprocessed_selected_features/test/aux.csv', index=False)
