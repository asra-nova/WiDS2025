# %%
from utils import get_data, threshold
import numpy as np
import matplotlib.pyplot as plt

# %%
X, Xs, y, X_df, y_df = get_data(
    "/Users/reza/School/2025/1-Spring/Advanced ML/Project/data/new/widsdatathon2025/TRAIN/TRAIN_FUNCTIONAL_CONNECTOME_MATRICES_new_36P_Pearson.csv",
    "/Users/reza/School/2025/1-Spring/Advanced ML/Project/data/new/preprocessed_selected_features/train/labels.csv",
    [0.4, 0.5, 0.6],
)

# %%
plt.hist(X.flatten(), bins=100)
# Out:
# (array([4.000000e+00, 2.000000e+00, 8.000000e+00, 6.000000e+00,
#         1.800000e+01, 2.600000e+01, 1.200000e+01, 5.200000e+01,
#         7.600000e+01, 1.620000e+02, 2.260000e+02, 4.240000e+02,
#         6.540000e+02, 1.164000e+03, 1.822000e+03, 3.174000e+03,
#         5.092000e+03, 8.382000e+03, 1.328800e+04, 2.049600e+04,
#         3.118400e+04, 4.754600e+04, 7.096000e+04, 1.041540e+05,
#         1.501040e+05, 2.118420e+05, 2.904980e+05, 3.941980e+05,
#         5.195900e+05, 6.736660e+05, 8.550380e+05, 1.062336e+06,
#         1.290136e+06, 1.525662e+06, 1.770824e+06, 2.007666e+06,
#         2.212390e+06, 2.390712e+06, 2.518640e+06, 2.586898e+06,
#         2.599766e+06, 2.562936e+06, 2.458028e+06, 2.323552e+06,
#         2.153520e+06, 1.969622e+06, 1.774214e+06, 1.578806e+06,
#         1.392572e+06, 1.223108e+06, 1.065168e+06, 9.272020e+05,
#         8.030060e+05, 6.908540e+05, 5.964060e+05, 5.134880e+05,
#         4.441140e+05, 3.804200e+05, 3.261920e+05, 2.795760e+05,
# ...

# %%
x1, x2, x3 = Xs

# %%
np.isnan(x3).any()
# Out:
# np.False_

# %%
x1.shape
# Out:
# (1213, 2, 200, 200)

# %%
plt.imshow(x1[0, 0] - x1[0, 1], cmap='gray')
plt.axis('off')
plt.show()

# %%
plt.imshow(x2[0, 0] - x2[0, 1], cmap='gray')
plt.axis('off')
plt.show()

# %%
plt.imshow(x3[0, 0] - x3[0, 1], cmap='gray')
plt.axis('off')
plt.colorbar()
plt.show()

# %%
(x2==x3).all()
# Out:
# np.False_
