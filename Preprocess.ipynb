# %%
import re
import numpy as np
import pandas as pd

# %%
# Load CSV file
df = pd.read_csv(
    "../Data/widsdatathon2025/TRAIN/TRAIN_FUNCTIONAL_CONNECTOME_MATRICES.csv"
)  # Adjust delimiter if needed

# %%
df.head()
# Out:
#   participant_id  0throw_1thcolumn  0throw_2thcolumn  0throw_3thcolumn  \
# 0   70z8Q2xdTXM3          0.093473          0.146902          0.067893
# 1   WHWymJu6zNZi          0.029580          0.179323          0.112933
# 2   4PAQp1M6EyAo         -0.051580          0.139734          0.068295
# 3   obEacy4Of68I          0.016273          0.204702          0.115980
# 4   s7WzzDcmDOhF          0.065771          0.098714          0.097604
#
#    0throw_4thcolumn  0throw_5thcolumn  0throw_6thcolumn  0throw_7thcolumn  \
# 0          0.015141          0.070221          0.063997          0.055382
# 1          0.038291          0.104899          0.064250          0.008488
# 2          0.046991          0.111085          0.026978          0.151377
# 3          0.043103          0.056431          0.057615          0.055773
# 4          0.112988          0.071139          0.085607          0.019392
#
#    0throw_8thcolumn  0throw_9thcolumn  ...  195throw_196thcolumn  \
# ...

# %%
199 * 199
# Out:
# 39601

# %%
matrix_positions = []
for col in df.columns[1:]:  # Skip participant_id
    match = re.match(r"(\d+)throw_(\d+)thcolumn", col)
    if match:
        row_idx, col_idx = map(int, match.groups())
        matrix_positions.append((row_idx, col_idx, col))

# Determine matrix shape
n_rows = max(pos[0] for pos in matrix_positions) + 1
n_columns = max(pos[1] for pos in matrix_positions) + 1

# %%
for index, row in df.iterrows():
    participant = row["participant_id"]
    matrix = np.zeros((n_rows, n_columns))  # Initialize empty matrix

    # Fill the matrix using the extracted column indices
    for row_idx, col_idx, col_name in matrix_positions:
        matrix[row_idx, col_idx] = row[col_name]

    print(f"Matrix for {participant}:\n", matrix.shape)
    break
    print()
# Out:
# Matrix for 70z8Q2xdTXM3:
#  (199, 200)

# %%
for c in df.columns[-200:]:
    print(c)
# Out:
# 179throw_190thcolumn
# 179throw_191thcolumn
# 179throw_192thcolumn
# 179throw_193thcolumn
# 179throw_194thcolumn
# 179throw_195thcolumn
# 179throw_196thcolumn
# 179throw_197thcolumn
# 179throw_198thcolumn
# 179throw_199thcolumn
# 180throw_181thcolumn
# 180throw_182thcolumn
# 180throw_183thcolumn
# 180throw_184thcolumn
# 180throw_185thcolumn
# 180throw_186thcolumn
# 180throw_187thcolumn
# 180throw_188thcolumn
# 180throw_189thcolumn
# 180throw_190thcolumn
# 180throw_191thcolumn
# 180throw_192thcolumn
# 180throw_193thcolumn
# 180throw_194thcolumn
# 180throw_195thcolumn
# 180throw_196thcolumn
# 180throw_197thcolumn
# 180throw_198thcolumn
# 180throw_199thcolumn
# 181throw_182thcolumn
# 181throw_183thcolumn
# 181throw_184thcolumn
# 181throw_185thcolumn
# 181throw_186thcolumn
# 181throw_187thcolumn
# 181throw_188thcolumn
# 181throw_189thcolumn
# 181throw_190thcolumn
# 181throw_191thcolumn
# 181throw_192thcolumn
# 181throw_193thcolumn
# 181throw_194thcolumn
# 181throw_195thcolumn
# ...
